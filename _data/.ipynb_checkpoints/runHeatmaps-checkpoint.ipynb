# %% [markdown]
# # Correr en cambio de año para actualizar aggregate data.
#
# Antes de correr, limpiar data en google sheets:
# - pasar año que terminó a "strava_clean"
# - dejar "strava" en blanco

# %%
# get dailymile-sque statistics
# !wget --no-check-certificate -O dailymilesque_stats.csv 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc/pub?gid=170553600&single=true&output=csv'

# get current year runs
# !wget --no-check-certificate -O running_data.csv 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc/pub?gid=291786965&single=true&output=csv'

# aggregate dailymile, garmingConnect, and strava runs into single file


# get garminConnect data (de primero pq tiene 3 columnas mas)
# !wget --no-check-certificate -O aggregate_data.csv 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc/pub?gid=633640415&single=true&output=csv'
# add new line
# !echo "" >> aggregate_data.csv
# get dailymile data
# !wget --no-check-certificate -O dailymile_data.csv 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc/pub?gid=1292540796&single=true&output=csv'
# append all lines except header to dailymile data
# !tail -n +2 dailymile_data.csv >> aggregate_data.csv
# remove dailymile data file
# !rm dailymile_data.csv
# add new line
# !echo "" >> aggregate_data.csv
# get strava data
# !wget --no-check-certificate -O strava_data.csv 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc/pub?gid=463736653&single=true&output=csv'
# append all lines except header to dailymile/garminConnect data
# !tail -n +2 strava_data.csv >> aggregate_data.csv
# remove strava data file
# !rm strava_data.csv

# %ls
# Out:
# --2022-01-03 12:39:12--  https://docs.google.com/spreadsheets/d/e/2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc/pub?gid=170553600&single=true&output=csv
# Resolving docs.google.com (docs.google.com)... 142.250.217.238, 2607:f8b0:4008:814::200e
# Connecting to docs.google.com (docs.google.com)|142.250.217.238|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://doc-0c-bk-sheets.googleusercontent.com/pub/70cmver1f290kjsnpar5ku2h9g/4a1u3gs9jijtki5fttnipn349s/1641235150000/114871121160870939545/*/e@2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc?gid=170553600&single=true&output=csv [following]
# Warning: wildcards not supported in HTTP.
# --2022-01-03 12:39:12--  https://doc-0c-bk-sheets.googleusercontent.com/pub/70cmver1f290kjsnpar5ku2h9g/4a1u3gs9jijtki5fttnipn349s/1641235150000/114871121160870939545/*/e@2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc?gid=170553600&single=true&output=csv
# Resolving doc-0c-bk-sheets.googleusercontent.com (doc-0c-bk-sheets.googleusercontent.com)... 142.250.217.193, 2607:f8b0:4008:80b::2001
# Connecting to doc-0c-bk-sheets.googleusercontent.com (doc-0c-bk-sheets.googleusercontent.com)|142.250.217.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘dailymilesque_stats.csv’
#
# dailymilesque_stats     [ <=>                ]     877  --.-KB/s    in 0s
#
# 2022-01-03 12:39:13 (4,24 MB/s) - ‘dailymilesque_stats.csv’ saved [877]
#
# --2022-01-03 12:39:14--  https://docs.google.com/spreadsheets/d/e/2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc/pub?gid=291786965&single=true&output=csv
# Resolving docs.google.com (docs.google.com)... 142.250.217.238, 2607:f8b0:4008:814::200e
# Connecting to docs.google.com (docs.google.com)|142.250.217.238|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://doc-0c-bk-sheets.googleusercontent.com/pub/70cmver1f290kjsnpar5ku2h9g/4a1u3gs9jijtki5fttnipn349s/1641235150000/114871121160870939545/*/e@2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc?gid=291786965&single=true&output=csv [following]
# Warning: wildcards not supported in HTTP.
# --2022-01-03 12:39:14--  https://doc-0c-bk-sheets.googleusercontent.com/pub/70cmver1f290kjsnpar5ku2h9g/4a1u3gs9jijtki5fttnipn349s/1641235150000/114871121160870939545/*/e@2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc?gid=291786965&single=true&output=csv
# Resolving doc-0c-bk-sheets.googleusercontent.com (doc-0c-bk-sheets.googleusercontent.com)... 142.250.217.193, 2607:f8b0:4008:80b::2001
# Connecting to doc-0c-bk-sheets.googleusercontent.com (doc-0c-bk-sheets.googleusercontent.com)|142.250.217.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘running_data.csv’
#
# running_data.csv        [ <=>                ]     235  --.-KB/s    in 0s
#
# 2022-01-03 12:39:15 (1,08 MB/s) - ‘running_data.csv’ saved [235]
#
# --2022-01-03 12:39:15--  https://docs.google.com/spreadsheets/d/e/2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc/pub?gid=633640415&single=true&output=csv
# Resolving docs.google.com (docs.google.com)... 142.250.217.238, 2607:f8b0:4008:814::200e
# Connecting to docs.google.com (docs.google.com)|142.250.217.238|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://doc-0c-bk-sheets.googleusercontent.com/pub/70cmver1f290kjsnpar5ku2h9g/bdgad4bg7o1k70r68qipn6dg7o/1641235155000/114871121160870939545/*/e@2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc?gid=633640415&single=true&output=csv [following]
# Warning: wildcards not supported in HTTP.
# --2022-01-03 12:39:16--  https://doc-0c-bk-sheets.googleusercontent.com/pub/70cmver1f290kjsnpar5ku2h9g/bdgad4bg7o1k70r68qipn6dg7o/1641235155000/114871121160870939545/*/e@2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc?gid=633640415&single=true&output=csv
# Resolving doc-0c-bk-sheets.googleusercontent.com (doc-0c-bk-sheets.googleusercontent.com)... 142.250.217.193, 2607:f8b0:4008:80b::2001
# Connecting to doc-0c-bk-sheets.googleusercontent.com (doc-0c-bk-sheets.googleusercontent.com)|142.250.217.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘aggregate_data.csv’
#
# aggregate_data.csv      [ <=>                ]   5,43K  --.-KB/s    in 0,003s
#
# 2022-01-03 12:39:17 (1,78 MB/s) - ‘aggregate_data.csv’ saved [5563]
#
# --2022-01-03 12:39:17--  https://docs.google.com/spreadsheets/d/e/2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc/pub?gid=1292540796&single=true&output=csv
# Resolving docs.google.com (docs.google.com)... 142.250.217.238, 2607:f8b0:4008:814::200e
# Connecting to docs.google.com (docs.google.com)|142.250.217.238|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://doc-0c-bk-sheets.googleusercontent.com/pub/70cmver1f290kjsnpar5ku2h9g/bdgad4bg7o1k70r68qipn6dg7o/1641235155000/114871121160870939545/*/e@2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc?gid=1292540796&single=true&output=csv [following]
# Warning: wildcards not supported in HTTP.
# --2022-01-03 12:39:18--  https://doc-0c-bk-sheets.googleusercontent.com/pub/70cmver1f290kjsnpar5ku2h9g/bdgad4bg7o1k70r68qipn6dg7o/1641235155000/114871121160870939545/*/e@2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc?gid=1292540796&single=true&output=csv
# Resolving doc-0c-bk-sheets.googleusercontent.com (doc-0c-bk-sheets.googleusercontent.com)... 142.250.217.193, 2607:f8b0:4008:80b::2001
# Connecting to doc-0c-bk-sheets.googleusercontent.com (doc-0c-bk-sheets.googleusercontent.com)|142.250.217.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘dailymile_data.csv’
#
# dailymile_data.csv      [ <=>                ]  22,23K  --.-KB/s    in 0,06s
#
# 2022-01-03 12:39:19 (392 KB/s) - ‘dailymile_data.csv’ saved [22765]
#
# --2022-01-03 12:39:19--  https://docs.google.com/spreadsheets/d/e/2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc/pub?gid=463736653&single=true&output=csv
# Resolving docs.google.com (docs.google.com)... 142.250.217.238, 2607:f8b0:4008:814::200e
# Connecting to docs.google.com (docs.google.com)|142.250.217.238|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://doc-0c-bk-sheets.googleusercontent.com/pub/70cmver1f290kjsnpar5ku2h9g/bdgad4bg7o1k70r68qipn6dg7o/1641235155000/114871121160870939545/*/e@2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc?gid=463736653&single=true&output=csv [following]
# Warning: wildcards not supported in HTTP.
# --2022-01-03 12:39:19--  https://doc-0c-bk-sheets.googleusercontent.com/pub/70cmver1f290kjsnpar5ku2h9g/bdgad4bg7o1k70r68qipn6dg7o/1641235155000/114871121160870939545/*/e@2PACX-1vTLPCB2D8_CdN4vCOS1VWLFspDh8uT6Rq4EzLW0e1JIhxUfgJqK5dsdrL7F3VLyrxXhhgNLNNzeSerc?gid=463736653&single=true&output=csv
# Resolving doc-0c-bk-sheets.googleusercontent.com (doc-0c-bk-sheets.googleusercontent.com)... 142.250.217.193, 2607:f8b0:4008:80b::2001
# Connecting to doc-0c-bk-sheets.googleusercontent.com (doc-0c-bk-sheets.googleusercontent.com)|142.250.217.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘strava_data.csv’
#
# strava_data.csv         [ <=>                ]   4,03K  --.-KB/s    in 0,002s
#
# 2022-01-03 12:39:20 (2,12 MB/s) - ‘strava_data.csv’ saved [4122]
#
# aggregate_data.csv       graphData.py*      running_data.csv
# dailymilesque_stats.csv  runHeatmaps.ipynb  updateData*

# %%
# https://calplot.readthedocs.io/en/latest/
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

import pandas as pd
import calplot
import datetime
import matplotlib.pyplot as plt

# %%
csv2read = "./running_data.csv"
dm_df = pd.read_csv(csv2read)
#xlsx2read = "~/Drive/IFTTT/runningData.xlsx"
#dm_df = pd.read_excel(xlsx2read)
dm_df.tail()
# Out:
#                                          fuente        date  distance (m)  \
# 0  https://www.strava.com/activities/5034620822  2022-03-29        3135.7
#
#    time (s)  distance (km)  ~energy (kcal) time (h:mm:ss) pace (min/km)   \
# 0      1293           3.14             292          21:33           6:52
#
#    climb (m)  cadence (spm)     country
# 0       12.1          153.5  Costa Rica

# %%
distances = dm_df['distance (km)']
#distances.dtype
dm_df.date = pd.to_datetime(dm_df['date'], format='%Y-%m-%d')
#dm_df.date.dtype
runs = dm_df.date
distances.index = runs
#print(isinstance(distances, pd.Series)) #Confirm that the object is a Series
distances
# Out:
# date
# 2022-03-29    3.14
# Name: distance (km), dtype: float64

# %%
# https://stackoverflow.com/questions/21321670/how-to-change-fonts-in-matplotlib-python

hoy = datetime.datetime.now()
output_image = "../assets/img/running_current"
#print(now.strftime("%Y-%m-%d %H:%M:%S"))
meses = ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Set', 'Oct', 'Nov', 'Dic']
dias_es = ['L','Ma','Mi','J','V','S','D']
plot = calplot.calplot(distances, yearascending=0, cmap='summer',
                monthlabels=meses, dayticks=False,
#                suptitle="distribución de km, 2021 [actualizado "+hoy.strftime("%Y-%m-%d")+"]"
               )

# plt.savefig(output_image+".pdf", transparent=True)
plt.savefig(output_image+".png", transparent=True)
# plt.savefig(output_image+".svg", transparent=True)
# !convert -trim "../assets/img/running_current.png" "../assets/img/running_current.png"
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.

# %%
csv2read = "./aggregate_data.csv"
dm_df = pd.read_csv(csv2read)
dm_df.tail()
# Out:
#                                            fuente                 Date  \
# 422  https://www.strava.com/activities/6356991280  2021-12-07 19:52:55
# 423  https://www.strava.com/activities/6368402457  2021-12-10 19:36:31
# 424  https://www.strava.com/activities/6385205704  2021-12-14 19:07:39
# 425  https://www.strava.com/activities/6405126618  2021-12-19 17:28:59
# 426  https://www.strava.com/activities/6444782805  2021-12-29 18:48:08
#
#      distance (m)  time (s)  distance (km) energy (kcal) time (hh:mm:ss)  \
# 422        4043.0      1617           4.04           377        26:57:00
# 423        3962.0      1577           3.96           369        26:17:00
# 424        4064.4      1667           4.06           379        27:47:00
# 425        4091.2      1605           4.09           381        26:45:00
# 426        5378.3      2240           5.38           501        37:20:00
#
#     pace (min/km)   climb (m)  cadence     country  aux_hours  aux_min  \
# 422           6:40       40.5    155.4  Costa Rica        NaN      NaN
# 423           6:38       40.2    157.2  Costa Rica        NaN      NaN
# 424           6:50       40.3    155.8  Costa Rica        NaN      NaN
# 425           6:32       40.4    156.8  Costa Rica        NaN      NaN
# 426           6:56       58.1    155.8  Costa Rica        NaN      NaN
#
#      aux_sec
# 422      NaN
# 423      NaN
# 424      NaN
# 425      NaN
# 426      NaN

# %%
distances = dm_df['distance (km)']
#distances.dtype
dm_df.Date = pd.to_datetime(dm_df['Date'], format='%Y-%m-%d')
#dm_df.date.dtype
runs = dm_df.Date
distances.index = runs
#print(isinstance(distances, pd.Series)) #Confirm that the object is a Series
distances
# Out:
# Date
# 2020-02-22 00:00:00    6.57
# 2020-02-24 00:00:00    5.88
# 2020-02-27 00:00:00    6.10
# 2020-02-29 00:00:00    6.16
# 2020-03-02 00:00:00    5.55
#                        ...
# 2021-12-07 19:52:55    4.04
# 2021-12-10 19:36:31    3.96
# 2021-12-14 19:07:39    4.06
# 2021-12-19 17:28:59    4.09
# 2021-12-29 18:48:08    5.38
# Name: distance (km), Length: 427, dtype: float64

# %%
# https://stackoverflow.com/questions/21321670/how-to-change-fonts-in-matplotlib-python

#hoy = datetime.datetime.now()
output_image = "../assets/img/running_aggregate"
#print(now.strftime("%Y-%m-%d %H:%M:%S"))
meses = ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Set', 'Oct', 'Nov', 'Dic']
dias_es = ['L','Ma','Mi','J','V','S','D']
plot = calplot.calplot(distances, yearascending=0, cmap='summer',
                monthlabels=meses, dayticks=False )

# plt.savefig(output_image+".pdf", transparent=True)
plt.savefig(output_image+".png", transparent=True)
# plt.savefig(output_image+".svg", transparent=True)
# !convert -trim "../assets/img/running_aggregate.png" "../assets/img/running_aggregate.png"
